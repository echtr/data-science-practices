# %%
# github.com/echtr

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("champs.csv", sep=";")

# %%
df
# Out:
#        Name     Class     Role Tier  Score  Trend   Win %  Role %  Pick %  \
# 0    Aatrox   Fighter      TOP  God  89.19  -1.82  49.85%  88.43%  10.23%
# 1      Ahri      Mage      MID    A  54.88  -7.09  50.61%  90.89%   5.15%
# 2     Akali  Assassin      MID    S  65.31  -9.59  48.29%  75.88%   9.71%
# 3     Akali  Assassin      TOP    B  42.97  -0.66  46.26%  22.86%   2.93%
# 4    Akshan  Marksman      MID    A  50.02   2.72  52.57%  65.92%   2.11%
# ..      ...       ...      ...  ...    ...    ...     ...     ...     ...
# 255  Zilean   Support  SUPPORT    A  51.46   5.20  51.60%  82.25%   2.65%
# 256  Zilean   Support      MID    A  50.92   6.31  52.26%  13.24%   0.39%
# 257     Zoe      Mage      MID    B  45.60  -3.40  48.61%  82.65%   2.55%
# 258     Zoe      Mage  SUPPORT    D  31.77   0.00  46.84%  13.97%   0.39%
# 259    Zyra      Mage  SUPPORT    A  54.33   5.84  53.30%  90.07%   3.37%
#
#       Ban %   KDA
# 0    24.26%  1.87
# 1     2.63%  2.41
# 2    16.95%  2.31
# ...

# %%
isimler = df["Name"][df["Name"].str.len() == 6].unique()

# %%
isimler
# Out:
# array(['Aatrox', 'Akshan', 'Anivia', 'Darius', 'Draven', 'Ezreal',
#        'Gragas', 'Graves', 'Illaoi', 'Irelia', "Kai'Sa", 'Kennen',
#        'Lillia', 'Lucian', 'Maokai', 'Qiyana', 'Rammus', 'Rengar',
#        'Rumble', 'Samira', 'Singed', 'Soraka', 'Syndra', 'Thresh',
#        'Twitch', 'Veigar', 'Viktor', 'Wukong', 'Xerath', 'Yorick',
#        'Zilean'], dtype=object)

# %%
for i in isimler:
    if "a" in i.lower() and "r" in i.lower() and "d" in i.lower():
        print(i)
# Out:
# Darius
# Draven
# Syndra
