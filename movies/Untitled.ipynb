# %%
# github.com/echtr

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("movies.csv")

# %%
df
# Out:
#                                    MOVIES         YEAR  \
# 0                           Blood Red Sky       (2021)
# 1     Masters of the Universe: Revelation     (2021– )
# 2                        The Walking Dead  (2010–2022)
# 3                          Rick and Morty     (2013– )
# 4                         Army of Thieves       (2021)
# ...                                   ...          ...
# 9994                       The Imperfects     (2021– )
# 9995                               Arcane     (2021– )
# 9996                    Heart of Invictus     (2022– )
# 9997                       The Imperfects     (2021– )
# 9998                       The Imperfects     (2021– )
#
#                                GENRE  RATING  \
# 0         [Action, Horror, Thriller]     6.1
# 1     [Animation, Action, Adventure]     5.0
# 2          [Drama, Horror, Thriller]     8.2
# 3     [Animation, Adventure, Comedy]     9.2
# 4            [Action, Crime, Horror]     NaN
# ...                              ...     ...
# 9994     [Adventure, Drama, Fantasy]     NaN
# 9995  [Animation, Action, Adventure]     NaN
# 9996            [Documentary, Sport]     NaN
# 9997     [Adventure, Drama, Fantasy]     NaN
# 9998     [Adventure, Drama, Fantasy]     NaN
#
#                                                ONE-LINE  \
# 0     \nA woman with a mysterious illness is forced ...
# 1     \nThe war for Eternia begins again in what may...
# 2     \nSheriff Deputy Rick Grimes wakes up from a c...
# 3     \nAn animated series that follows the exploits...
# 4     \nA prequel, set before the events of Army of ...
# ...                                                 ...
# 9994                                     \nAdd a Plot\n
# 9995                                     \nAdd a Plot\n
# 9996                                     \nAdd a Plot\n
# 9997                                     \nAdd a Plot\n
# 9998                                     \nAdd a Plot\n
#
#                                                   STARS    VOTES  RunTime  \
# 0     \n    Director:\nPeter Thorwarth\n| \n    Star...   21,062    121.0
# 1     \n            \n    Stars:\nChris Wood, \nSara...   17,870     25.0
# 2     \n            \n    Stars:\nAndrew Lincoln, \n...  885,805     44.0
# 3     \n            \n    Stars:\nJustin Roiland, \n...  414,849     23.0
# 4     \n    Director:\nMatthias Schweighöfer\n| \n  ...      NaN      NaN
# ...                                                 ...      ...      ...
# 9994  \n            \n    Stars:\nMorgan Taylor Camp...      NaN      NaN
# 9995                                                 \n      NaN      NaN
# 9996  \n    Director:\nOrlando von Einsiedel\n| \n  ...      NaN      NaN
# 9997  \n    Director:\nJovanka Vuckovic\n| \n    Sta...      NaN      NaN
# 9998  \n    Director:\nJovanka Vuckovic\n| \n    Sta...      NaN      NaN
#
#      Gross
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ...    ...
# 9994   NaN
# 9995   NaN
# 9996   NaN
# 9997   NaN
# 9998   NaN
#
# [9919 rows x 9 columns]

# %%
df.isna().sum()
# Out:
# MOVIES         0
# YEAR         603
# GENRE          0
# RATING      1751
# ONE-LINE       0
# STARS          0
# VOTES       1751
# RunTime     2887
# Gross       9459
# dtype: int64

# %%
df["GENRE"] = df["GENRE"].str[1:]
df["GENRE"]
# Out:
# 0           Action, Horror, Thriller
# 1       Animation, Action, Adventure
# 2            Drama, Horror, Thriller
# 3       Animation, Adventure, Comedy
# 4              Action, Crime, Horror
#                           ...
# 9994       Adventure, Drama, Fantasy
# 9995    Animation, Action, Adventure
# 9996              Documentary, Sport
# 9997       Adventure, Drama, Fantasy
# 9998       Adventure, Drama, Fantasy
# Name: GENRE, Length: 9999, dtype: object

# %%
#df["GENRE"] = df["GENRE"].str.split("")
#df["GENRE"]

# %%
df.head(1)
# Out:
#           MOVIES    YEAR                                 GENRE  RATING  \
# 0  Blood Red Sky  (2021)  Action, Horror, Thriller                 6.1
#
#                                             ONE-LINE  \
# 0  \nA woman with a mysterious illness is forced ...
#
#                                                STARS   VOTES  RunTime Gross
# 0  \n    Director:\nPeter Thorwarth\n| \n    Star...  21,062    121.0   NaN

# %%
df["GENRE"] = df["GENRE"].str.replace(" ","")

# %%
df["GENRE"] = df["GENRE"].str.split(",")

# %%
df.head(1)
# Out:
#           MOVIES    YEAR                       GENRE  RATING  \
# 0  Blood Red Sky  (2021)  [Action, Horror, Thriller]     6.1
#
#                                             ONE-LINE  \
# 0  \nA woman with a mysterious illness is forced ...
#
#                                                STARS   VOTES  RunTime Gross
# 0  \n    Director:\nPeter Thorwarth\n| \n    Star...  21,062    121.0   NaN

# %%
#df[df['GENRE'].apply(lambda x: 'Action' in x)]

# %%
df["GENRE"].dtype
# Out:
# dtype('O')

# %%
df = df.dropna(subset = ["GENRE"])

# %%
df
# Out:
# MOVIES         0
# YEAR         603
# GENRE          0
# RATING      1751
# ONE-LINE       0
# STARS          0
# VOTES       1751
# RunTime     2887
# Gross       9459
# dtype: int64

# %%
df[df['GENRE'].apply(lambda x: 'Fantasy' in x)]
# Out:
#                   MOVIES         YEAR                         GENRE  RATING  \
# 11               Lucifer  (2016–2021)       [Crime, Drama, Fantasy]     8.1
# 19       Stranger Things     (2016– )      [Drama, Fantasy, Horror]     8.7
# 28          Supernatural  (2005–2020)      [Drama, Fantasy, Horror]     8.4
# 37           The Witcher     (2019– )  [Action, Adventure, Fantasy]     8.2
# 43             Outlander     (2014– )     [Drama, Fantasy, Romance]     8.4
# ...                  ...          ...                           ...     ...
# 9922   Girl From Nowhere     (2018– )       [Crime, Drama, Fantasy]     8.1
# 9935      The Imperfects     (2021– )   [Adventure, Drama, Fantasy]     NaN
# 9994      The Imperfects     (2021– )   [Adventure, Drama, Fantasy]     NaN
# 9997      The Imperfects     (2021– )   [Adventure, Drama, Fantasy]     NaN
# 9998      The Imperfects     (2021– )   [Adventure, Drama, Fantasy]     NaN
#
#                                                ONE-LINE  \
# 11    \nLucifer Morningstar has decided he's had eno...
# 19    \nWhen a young boy disappears, his mother, a p...
# 28    \nTwo brothers follow their father's footsteps...
# 37    \nGeralt of Rivia, a solitary monster hunter, ...
# 43    \nAn English combat nurse from 1945 is mysteri...
# ...                                                 ...
# 9922  \nNanno and Yuri's rivalry comes to a head ove...
# 9935                                     \nAdd a Plot\n
# 9994                                     \nAdd a Plot\n
# 9997                                     \nAdd a Plot\n
# 9998                                     \nAdd a Plot\n
#
#                                                   STARS    VOTES  RunTime  \
# 11    \n            \n    Stars:\nTom Ellis, \nLesle...  264,222     42.0
# 19    \n            \n    Stars:\nMillie Bobby Brown...  885,856     51.0
# 28    \n            \n    Stars:\nJared Padalecki, \...  404,273     44.0
# 37    \n            \n    Stars:\nHenry Cavill, \nAn...  336,484     60.0
# 43    \n            \n    Stars:\nCaitriona Balfe, \...  134,991     64.0
# ...                                                 ...      ...      ...
# 9922  \n    Director:\nKomgrit Triwimol\n| \n    Sta...      112      NaN
# 9935  \n            \n    Stars:\nMorgan Taylor Camp...      NaN      NaN
# 9994  \n            \n    Stars:\nMorgan Taylor Camp...      NaN      NaN
# 9997  \n    Director:\nJovanka Vuckovic\n| \n    Sta...      NaN      NaN
# 9998  \n    Director:\nJovanka Vuckovic\n| \n    Sta...      NaN      NaN
#
#      Gross
# 11     NaN
# 19     NaN
# 28     NaN
# 37     NaN
# 43     NaN
# ...    ...
# 9922   NaN
# 9935   NaN
# 9994   NaN
# 9997   NaN
# 9998   NaN
#
# [572 rows x 9 columns]
