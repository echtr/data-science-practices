# %%
# github.com/echtr

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("energy.csv")

# %%
df
# Out:
#            Entity  Year  Access to electricity (% of population)  \
# 0     Afghanistan  2000                                 1.613591
# 1     Afghanistan  2001                                 4.074574
# 2     Afghanistan  2002                                 9.409158
# 3     Afghanistan  2003                                14.738506
# 4     Afghanistan  2004                                20.064968
# ...           ...   ...                                      ...
# 3644     Zimbabwe  2016                                42.561730
# 3645     Zimbabwe  2017                                44.178635
# 3646     Zimbabwe  2018                                45.572647
# 3647     Zimbabwe  2019                                46.781475
# 3648     Zimbabwe  2020                                52.747670
#
#       Access to clean fuels for cooking  \
# 0                                   6.2
# 1                                   7.2
# 2                                   8.2
# ...

# %%
df.shape, df.isnull().sum(), df.dtypes
# Out:
# ((3649, 21),
#  Entity                                                                 0
#  Year                                                                   0
#  Access to electricity (% of population)                               10
#  Access to clean fuels for cooking                                    169
#  Renewable-electricity-generating-capacity-per-capita                 931
#  Financial flows to developing countries (US $)                      2089
#  Renewable energy share in the total final energy consumption (%)     194
#  Electricity from fossil fuels (TWh)                                   21
#  Electricity from nuclear (TWh)                                       126
#  Electricity from renewables (TWh)                                     21
#  Low-carbon electricity (% electricity)                                42
#  Primary energy consumption per capita (kWh/person)                     0
# ...

# %%
t = "Access to electricity (% of population)"

#df.Year == 2020 and 
df[df.Entity == "Turkey"].sort_values(by=[t])
# Out:
#       Entity  Year  Access to electricity (% of population)  \
# 3364  Turkey  2009                                99.850876
# 3363  Turkey  2008                                99.880860
# 3362  Turkey  2007                                99.923170
# 3361  Turkey  2006                                99.960724
# 3360  Turkey  2005                                99.987030
# 3359  Turkey  2004                                99.997990
# 3355  Turkey  2000                               100.000000
# 3373  Turkey  2018                               100.000000
# 3372  Turkey  2017                               100.000000
# 3371  Turkey  2016                               100.000000
# 3370  Turkey  2015                               100.000000
# 3369  Turkey  2014                               100.000000
# 3368  Turkey  2013                               100.000000
# 3365  Turkey  2010                               100.000000
# 3366  Turkey  2011                               100.000000
# ...

# %%
import matplotlib.pyplot as plt

# %%
x = df["Year"].unique()
y = df[df.Entity == "Turkey"]["gdp_per_capita"].to_numpy()
plt.figure(figsize=(20,6))
plt.plot(x, y)
plt.title("GDP of Turkey")
plt.xlabel("Years")
plt.ylabel("USD$")
plt.show()

# %%
df[df.Year == 2020].sort_values(by=["Access to electricity (% of population)"], ascending=False)

#En iyi olan 1848. satır, en kötü olan 3102. satır
# Out:
#                         Entity  Year  Access to electricity (% of population)  \
# 1848                    Latvia  2020                               100.000000
# 2947                Seychelles  2020                               100.000000
# 1617                   Ireland  2020                               100.000000
# 1596                      Iraq  2020                               100.000000
# 2786     Saint Kitts and Nevis  2020                               100.000000
# ...                        ...   ...                                      ...
# 671   Central African Republic  2020                                15.465084
# 2016                    Malawi  2020                                14.866769
# 566                    Burundi  2020                                11.735556
# 692                       Chad  2020                                11.080117
# 3102               South Sudan  2020                                 7.241338
#
# ...

# %%
best = df.loc[1848].to_frame().T
worst = df.loc[3102].to_frame().T
ndf = pd.concat([best, worst]).reset_index().drop(columns=["index"]) #ndf = new_df
ndf
# Out:
#         Entity  Year Access to electricity (% of population)  \
# 0       Latvia  2020                                   100.0
# 1  South Sudan  2020                                7.241338
#
#   Access to clean fuels for cooking  \
# 0                             100.0
# 1                               0.0
#
#   Renewable-electricity-generating-capacity-per-capita  \
# 0                                                NaN
# 1                                               0.06
#
#   Financial flows to developing countries (US $)  \
# 0                                            NaN
# 1                                            NaN
#
#   Renewable energy share in the total final energy consumption (%)  \
# 0                                                NaN
# 1                                                NaN
#
#   Electricity from fossil fuels (TWh) Electricity from nuclear (TWh)  \
# 0                                2.08                            0.0
# ...
